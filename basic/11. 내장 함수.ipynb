# %%
chr(65)
# Out:
# 'A'

# %%
ord("A")
# Out:
# 65

# %%
password = "test123"

for i in password:
    print(chr(ord(i) * 100), end="")
# Out:
# ⵐ❴ⳬⵐጤᎈᏬ

# %%
expression = input("수식을 입력하세요.\nex)10+10\n")
# Out:
# 수식을 입력하세요.
# ex)10+10
#  150*1234

# %%
eval(expression)
# Out:
# 185100

# %%
data1 = print(format(1000000, ","))
data2 = print(format(1000000, "_"))
# Out:
# 1,000,000
# 1_000_000

# %%
int(data1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 int(data1)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'

# %%
divmod(10, 2)
# Out:
# (5, 0)

# %%
round(3.141592)
# Out:
# 3

# %%
# 오사오입
# 값이 1~4까지면 버림
# 값이 5일 때
# 앞 자리가 홀수면 올림
# 앞 자리가 짝수면 버림

round(2.5)
# Out:
# 2

# %%
0.1 + 0.2
# Out:
# 0.30000000000000004

# %% [markdown]
# ### 문자열 함수

# %%
# count
"abcdee".count("e")
# Out:
# 2

# %%
"abcdee".find("e")
# Out:
# 4

# %%
"asadadasadadadad".rfind("a")
# Out:
# 14

# %%
"a".upper()
# Out:
# 'A'

# %%
"A".lower()
# Out:
# 'a'

# %%
"apple".capitalize()
# Out:
# 'Apple'

# %%
li4 = [(i + 1) * 10 for i in range(5)]

# %%
li4
# Out:
# [10, 20, 30, 40, 50]

# %%
", ".join(li4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 ", ".join(li4)
#
# TypeError: sequence item 0: expected str instance, int found

# %%
"10".isdigit()

# %%
# 문자가 포함되었는지 확인하는 메서드
num1.isalpha()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 2
#       1 # 문자가 포함되었는지 확인하는 메서드
# ----> 2 num1.isalpha()
#
# AttributeError: 'bool' object has no attribute 'isalpha'

# %%
data3 = "*******************3*********3********3***********"

# %%
data3[data3.find("3"):]
# Out:
# '3*********3********3***********'

# %%
data3.lstrip("*")
# Out:
# '3*********3********3***********'

# %%
data3.rstrip("*")
# Out:
# '*******************3*********3********3'

# %%
data3.strip("*")
# Out:
# '3*********3********3'

# %%
"2123.235323.2343.234353.44".split(".")
# Out:
# ['2123', '235323', '2343', '234353', '44']

# %%
names = "짱구", "하영", "수지"
score = 20, 40, 60

# %%
for i in zip(names, score):
    print(i)
# Out:
# ('짱구', 20)
# ('하영', 40)
# ('수지', 60)
