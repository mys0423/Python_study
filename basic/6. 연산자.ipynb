# %% [markdown]
# 1. 단항

# %%
# ! 시스템 모듈을 호출 명령어
# not
print(10 + -20)
print(not not True)
print(not 10)
print(not 20)
# Out:
# -10
# True
# False
# False

# %% [markdown]
# 2. 산술연산자

# %%
print(15 // 4)
print(15 / 4)
# Out:
# 3
# 3.75

# %%
print(10 % 3)
# Out:
# 1

# %%
print(10 * 2)
# Out:
# 20

# %%
print(10 ** 2)
# Out:
# 100

# %% [markdown]
# ### 3. 시퀀스 연산자
# - **순서가 있는 자료구조에서 사용할 수 있는 연산자(*, +)

# %%
# 인덱싱
print("abcdefg"[-1])
# Out:
# g

# %%
# 연결(+) - 시퀀스 연산자
print("apple" + "banana")
# Out:
# applebanana

# %%
# 시퀀스 연산자(*) - 반복
print(10 * '2')
# Out:
# 2222222222

# %%
print("apple" * 5)
# Out:
# appleappleappleappleapple

# %% [markdown]
# 누적복합연산자

# %%
money = 70000000
print(money)
# Out:
# 70000000

# %%
money /= 2000
money *= 80202
print(money)
# Out:
# 2807070000.0

# %%
print(10 >> 2)
# Out:
# 2

# %%
print(16 << 2)
# Out:
# 64

# %%
64 << 2
# Out:
# 256

# %%
# bin: 2진수
print(bin(10))
# Out:
# 0b1010

# %%
print(hex(16))
# Out:
# 0x10

# %%
print(bin(10))
print(bin(11))
# Out:
# 0b1010
# 0b1011

# %%
# 논리합(|)
# 하나라도 1이면 1
print(10 | 11)
# Out:
# 11

# %%
# 논리곱(&)
# 둘다 1이면 1, 하나라도 0이면 0
print(10 & 11)
# Out:
# 10

# %%
# xor(^)
# 모두 같으면 0 아니면 1
print(10 ^ 11)
# Out:
# 1

# %%
# not(~)
print(~10)
# Out:
# -11

# %% [markdown]
# ## 6. 관계 연산자

# %%
print(20 < 19) # 미만
print(15 < 87)
# Out:
# False
# True

# %% [markdown]
# ## 7. 논리 연산자(and, or)

# %%
print(10 > 5 and 100 == True)
# Out:
# False

# %%
print(bool(10))
# Out:
# True

# %%
print(10 < 5 or True)
# Out:
# True

# %%
# 초기값
print(10 < 5 or 10)
# Out:
# 10

# %%
num = 10

# %% [markdown]
# ## 8. 삼항 연산자

# %%
bool("True" if 11 == 10 else "False")
# Out:
# True

# %%
# 삼항 두 수 비교
num1 = input("첫 번째 정수\n")
num2 = input("두 번째 정수\n")

print(num1 if num1 > num2 else "두 수가 같습니다" if num1 == num2 else num2)
# Out:
# 첫 번째 정수
#  10
# 두 번째 정수
#  10
# 두 수가 같습니다

# %%
# 삼항 연산자 엔터치면 안됨.
# 들여쓰기로 영역 구분

# %%
# 사용자에게 정수 또는 실수를 입력 받아서
# 정수인지 실수인지 확인 후 삼항 연산자로 결과를 출력하시오.
# ex) 10 -> "정수"
# ex) 11.0 -> "정수"
# ex) 11.3 -> "실수"
num: float = float(input("수 입력\n"))
print("실수" if bool(num % 1)  else "정수")
# Out:
# 수 입력
#  10.0
# 정수
