# %%
# import 모듈
# import 모듈명1, 모듈명2
# from 모듈명 import 모듈이름1, 모듈이름2
import random

# %%
random.randint(10, 100)
# Out:
# 65

# %%
random.randrange(1, 10000, 5)
# Out:
# 8861

# %%
print(random.sample(lotto, 6))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(random.sample(lotto, 1))
#
# File C:\python311\Lib\random.py:439, in Random.sample(self, population, k, counts)
#     415 # Sampling without replacement entails tracking either potential
#     416 # selections (the pool) in a list or previous selections in a set.
#     417
#    (...)    435 # too many calls to _randbelow(), making them slower and
#     436 # causing them to eat more entropy than necessary.
#     438 if not isinstance(population, _Sequence):
# --> 439     raise TypeError("Population must be a sequence.  "
#     440                     "For dicts or sets, use sorted(d).")
#     441 n = len(population)
#     442 if counts is not None:
#
# TypeError: Population must be a sequence.  For dicts or sets, use sorted(d).

# %%
import IPython

# %%
from IPython.display import Image, YouTubeVideo

# %%
Image(url="https://search.pstatic.net/sunny/?src=https%3A%2F%2Fyt3.ggpht.com%2Fa-%2FAAuE7mCML_BI0RIMlxJr84lluToD-Vg39DxtYPdkmA%3Ds900-mo-c-c0xffffffff-rj-k-no&type=a340")
# Out:
# <img src="https://search.pstatic.net/sunny/?src=https%3A%2F%2Fyt3.ggpht.com%2Fa-%2FAAuE7mCML_BI0RIMlxJr84lluToD-Vg39DxtYPdkmA%3Ds900-mo-c-c0xffffffff-rj-k-no&type=a340"/>

# %%
YouTubeVideo("")

# %%
from datetime import datetime

now = datetime.now()
print(now.month)
# Out:
# 5
