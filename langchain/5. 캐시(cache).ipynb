# %%
from dotenv import load_dotenv
import os

load_dotenv()
print(os.environ.get('OPENAI_API_KEY')[:20])

# v1.2.6
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.globals import set_llm_cache
from langchain_core.caches import InMemoryCache
# Out:
# sk-proj-GGHq2YjvxskA

# %%
in_memory_cache = InMemoryCache()
set_llm_cache(in_memory_cache)

# %%
chat = ChatOpenAI(temperature=0.1)

# %%
import time
from datetime import timedelta

# %%
def check_laptime(message):

    start_time = time.time()
    response = chat.invoke(message)
    end_time = time.time()

    elapsed_time = end_time - start_time
    print(f"경과 시간: {str(timedelta(seconds=elapsed_time))}")
    print(f"글자 수: {len(response.content)}")
    print(response.content)

# %%
check_laptime("피자를 만드는 방법에 대해서 알려줘!")
# Out:
# 경과 시간: 0:00:05.283758
# 글자 수: 464
# 피자를 만드는 방법은 다음과 같습니다:
#
# 1. 준비물: 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일, 토마토 소스, 치즈, 토핑 재료(페퍼로니, 양파, 피망 등)
#
# 2. 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일을 섞어 반죽을 만든다. 반죽을 만들 때는 밀가루와 물의 비율을 적절히 조절하여 탄력 있는 반죽이 되도록 한다.
#
# 3. 반죽을 반쯤 발효시킨 후 도우를 미는데 필요한 크기로 나누고 도우를 미는데 필요한 크기로 나눈다.
#
# 4. 도우를 미는데 필요한 크기로 나누고 도우를 미는데 필요한 크기로 나눈다.
#
# 5. 도우 위에 토마토 소스를 발라준 후 치즈와 토핑 재료를 올린다.
#
# 6. 피자를 200도로 예열된 오븐에 넣고 15-20분간 굽는다.
#
# 7. 굽기 전에 피자 위에 올리브 오일을 조금 뿌려주면 더 맛있는 피자가 완성된다.
#
# 이렇게 하면 집에서 간단하게 맛있는 피자를 만들 수 있습니다. 맛있게 즐겨보세요!

# %%
check_laptime("야다....")
# Out:
# 경과 시간: 0:00:02.748933
# 글자 수: 18
# 안녕하세요! 무엇을 도와드릴까요?

# %%
print(in_memory_cache._cache)
# Out:
# {('[{"lc": 1, "type": "constructor", "id": ["langchain", "schema", "messages", "HumanMessage"], "kwargs": {"content": "\\ud53c\\uc790\\ub97c \\ub9cc\\ub4dc\\ub294 \\ubc29\\ubc95\\uc5d0 \\ub300\\ud574\\uc11c \\uc54c\\ub824\\uc918!", "type": "human"}}]', '{"id": ["langchain", "chat_models", "openai", "ChatOpenAI"], "kwargs": {"model_name": "gpt-3.5-turbo", "openai_api_key": {"id": ["OPENAI_API_KEY"], "lc": 1, "type": "secret"}, "openai_proxy": null, "output_version": null, "stream_usage": true, "temperature": 0.1}, "lc": 1, "name": "ChatOpenAI", "type": "constructor"}---[(\'stop\', None)]'): [ChatGeneration(text='피자를 만드는 방법은 다음과 같습니다:\n\n1. 준비물: 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일, 토마토 소스, 치즈, 토핑 재료(페퍼로니, 양파, 피망 등)\n\n2. 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일을 섞어 반죽을 만든다. 반죽을 만들 때는 밀가루와 물의 비율을 적절히 조절하여 탄력 있는 반죽이 되도록 한다.\n\n3. 반죽을 반쯤 발효시킨 후 도우를 미는데 필요한 크기로 나누고 도우를 미는데 필요한 크기로 나눈다.\n\n4. 도우를 미는데 필요한 크기로 나누고 도우를 미는데 필요한 크기로 나눈다.\n\n5. 도우 위에 토마토 소스를 발라준 후 치즈와 토핑 재료를 올린다.\n\n6. 피자를 200도로 예열된 오븐에 넣고 15-20분간 굽는다.\n\n7. 굽기 전에 피자 위에 올리브 오일을 조금 뿌려주면 더 맛있는 피자가 완성된다.\n\n이렇게 하면 집에서 간단하게 맛있는 피자를 만들 수 있습니다. 맛있게 즐겨보세요!', generation_info={'finish_reason': 'stop', 'logprobs': None}, message=AIMessage(content='피자를 만드는 방법은 다음과 같습니다:\n\n1. 준비물: 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일, 토마토 소스, 치즈, 토핑 재료(페퍼로니, 양파, 피망 등)\n\n2. 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일을 섞어 반죽을 만든다. 반죽을 만들 때는 밀가루와 물의 비율을 적절히 조절하여 탄력 있는 반죽이 되도록 한다.\n\n3. 반죽을 반쯤 발효시킨 후 도우를 미는데 필요한 크기로 나누고 도우를 미는데 필요한 크기로 나눈다.\n\n4. 도우를 미는데 필요한 크기로 나누고 도우를 미는데 필요한 크기로 나눈다.\n\n5. 도우 위에 토마토 소스를 발라준 후 치즈와 토핑 재료를 올린다.\n\n6. 피자를 200도로 예열된 오븐에 넣고 15-20분간 굽는다.\n\n7. 굽기 전에 피자 위에 올리브 오일을 조금 뿌려주면 더 맛있는 피자가 완성된다.\n\n이렇게 하면 집에서 간단하게 맛있는 피자를 만들 수 있습니다. 맛있게 즐겨보세요!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 480, 'prompt_tokens': 28, 'total_tokens': 508, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfIjI4Jq74kNrbPf27bcQX4ZN3dv3', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e24ea-9d92-7fb3-8b00-3f460a6eb743-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 28, 'output_tokens': 480, 'total_tokens': 508, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}))]}

# %%
for i in in_memory_cache._cache.keys():
    print(i)
# Out:
# ('[{"lc": 1, "type": "constructor", "id": ["langchain", "schema", "messages", "HumanMessage"], "kwargs": {"content": "\\ud53c\\uc790\\ub97c \\ub9cc\\ub4dc\\ub294 \\ubc29\\ubc95\\uc5d0 \\ub300\\ud574\\uc11c \\uc54c\\ub824\\uc918!", "type": "human"}}]', '{"id": ["langchain", "chat_models", "openai", "ChatOpenAI"], "kwargs": {"model_name": "gpt-3.5-turbo", "openai_api_key": {"id": ["OPENAI_API_KEY"], "lc": 1, "type": "secret"}, "openai_proxy": null, "output_version": null, "stream_usage": true, "temperature": 0.1}, "lc": 1, "name": "ChatOpenAI", "type": "constructor"}---[(\'stop\', None)]')

# %%
for i in in_memory_cache._cache.values():
    print(i)
# Out:
# [ChatGeneration(text='피자를 만드는 방법은 다음과 같습니다:\n\n1. 준비물: 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일, 토마토 소스, 치즈, 토핑 재료(페퍼로니, 양파, 피망 등)\n\n2. 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일을 섞어 반죽을 만든다. 반죽을 만들 때는 밀가루와 물의 비율을 적절히 조절하여 탄력 있는 반죽이 되도록 한다.\n\n3. 반죽을 반쯤 발효시킨 후 도우를 미는데 필요한 크기로 나누고 도우를 미는데 필요한 크기로 나눈다.\n\n4. 도우를 미는데 필요한 크기로 나누고 도우를 미는데 필요한 크기로 나눈다.\n\n5. 도우 위에 토마토 소스를 발라준 후 치즈와 토핑 재료를 올린다.\n\n6. 피자를 200도로 예열된 오븐에 넣고 15-20분간 굽는다.\n\n7. 굽기 전에 피자 위에 올리브 오일을 조금 뿌려주면 더 맛있는 피자가 완성된다.\n\n이렇게 하면 집에서 간단하게 맛있는 피자를 만들 수 있습니다. 맛있게 즐겨보세요!', generation_info={'finish_reason': 'stop', 'logprobs': None}, message=AIMessage(content='피자를 만드는 방법은 다음과 같습니다:\n\n1. 준비물: 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일, 토마토 소스, 치즈, 토핑 재료(페퍼로니, 양파, 피망 등)\n\n2. 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일을 섞어 반죽을 만든다. 반죽을 만들 때는 밀가루와 물의 비율을 적절히 조절하여 탄력 있는 반죽이 되도록 한다.\n\n3. 반죽을 반쯤 발효시킨 후 도우를 미는데 필요한 크기로 나누고 도우를 미는데 필요한 크기로 나눈다.\n\n4. 도우를 미는데 필요한 크기로 나누고 도우를 미는데 필요한 크기로 나눈다.\n\n5. 도우 위에 토마토 소스를 발라준 후 치즈와 토핑 재료를 올린다.\n\n6. 피자를 200도로 예열된 오븐에 넣고 15-20분간 굽는다.\n\n7. 굽기 전에 피자 위에 올리브 오일을 조금 뿌려주면 더 맛있는 피자가 완성된다.\n\n이렇게 하면 집에서 간단하게 맛있는 피자를 만들 수 있습니다. 맛있게 즐겨보세요!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 480, 'prompt_tokens': 28, 'total_tokens': 508, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfIjI4Jq74kNrbPf27bcQX4ZN3dv3', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e24ea-9d92-7fb3-8b00-3f460a6eb743-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 28, 'output_tokens': 480, 'total_tokens': 508, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}))]

# %%
# 캐시 삭제
in_memory_cache.clear()

# %%
in_memory_cache._cache
# Out:
# {}

# %% [markdown]
# ## 디버그 설정

# %%
from langchain_core.globals import set_debug

# %%
set_debug(True)

# %%
chat.invoke("랍스터는 누구의 후손이니?")
# Out:
# [llm/start] [llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: 랍스터는 누구의 후손이니?"
#   ]
# }
# [llm/end] [llm:ChatOpenAI] s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "랍스터는 게의 후손입니다.",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "랍스터는 게의 후손입니다.",
#             "additional_kwargs": {
#               "refusal": null
#             },
#             "response_metadata": {
#               "token_usage": {
#                 "completion_tokens": 12,
#                 "prompt_tokens": 23,
#                 "total_tokens": 35,
#                 "completion_tokens_details": {
#                   "accepted_prediction_tokens": 0,
#                   "audio_tokens": 0,
#                   "reasoning_tokens": 0,
#                   "rejected_prediction_tokens": 0
#                 },
#                 "prompt_tokens_details": {
#                   "audio_tokens": 0,
#                   "cached_tokens": 0
#                 }
#               },
#               "model_provider": "openai",
#               "model_name": "gpt-3.5-turbo-0125",
#               "system_fingerprint": null,
#               "id": "chatcmpl-DfIp2aSenpWbFNKS0RINxwf50MNTk",
#               "service_tier": "default",
#               "finish_reason": "stop",
#               "logprobs": null
#             },
#             "type": "ai",
#             "id": "lc_run--019e24f0-0e74-76e3-b47a-2c5b1ef80550-0",
#             "usage_metadata": {
#               "input_tokens": 23,
#               "output_tokens": 12,
#               "total_tokens": 35,
#               "input_token_details": {
#                 "audio": 0,
#                 "cache_read": 0
#               },
#               "output_token_details": {
#                 "audio": 0,
#                 "reasoning": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 12,
#       "prompt_tokens": 23,
#       "total_tokens": 35,
#       "completion_tokens_details": {
#         "accepted_prediction_tokens": 0,
#         "audio_tokens": 0,
#         "reasoning_tokens": 0,
#         "rejected_prediction_tokens": 0
#       },
#       "prompt_tokens_details": {
#         "audio_tokens": 0,
#         "cached_tokens": 0
#       }
#     },
#     "model_provider": "openai",
#     "model_name": "gpt-3.5-turbo-0125",
#     "system_fingerprint": null,
#     "id": "chatcmpl-DfIp2aSenpWbFNKS0RINxwf50MNTk",
#     "service_tier": "default"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# AIMessage(content='랍스터는 게의 후손입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 23, 'total_tokens': 35, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfIp2aSenpWbFNKS0RINxwf50MNTk', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e24f0-0e74-76e3-b47a-2c5b1ef80550-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 23, 'output_tokens': 12, 'total_tokens': 35, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
