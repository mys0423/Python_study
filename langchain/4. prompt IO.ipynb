# %% [markdown]
# ## 프롬프트 저장, 불러오기

# %% [markdown]
# ## json

# %%
from dotenv import load_dotenv
import os

load_dotenv()
print(os.environ.get('OPENAI_API_KEY')[:20])
# Out:
# sk-proj-GGHq2YjvxskA

# %%
base_path = r"D:\back_0900_mys\python\resource"

# %%
base_path
# Out:
# 'D:\\back_0900_mys\\python\\resource'

# %%
file_path = os.path.join(base_path, "prompt.json")

# %%
file_path
# Out:
# 'D:\\back_0900_mys\\python\\resource\\prompt.json'

# %%
with open(file_path, "w") as f:
    f.write("""
        {
            "_type": "prompt",
            "template": "{country}에 대해서 어떻게 알고 있어요?",
            "input_varoables": ["country"]
        }
    """)

# %%
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.prompts import load_prompt

# %%
chat = ChatOpenAI(temperature=0.1)

# %%
prompt = load_prompt(file_path)

# %%
chain = prompt | chat

# %%
result = chain.invoke({
    "country": "한국"
})

# %%
print(result.content)
# Out:
# 한국은 동아시아에 위치한 나라로, 수도는 서울입니다. 한국은 역사적으로 중국과 일본의 영향을 받았으며, 한글이라는 고유의 문자를 사용합니다. 한국은 전통적인 문화와 현대적인 발전이 조화롭게 이루어진 나라로, K-pop, K-drama, 한식 음식 등이 전 세계적으로 인기를 끌고 있습니다. 또한 한국은 세계적으로 유명한 기업들이 많이 발달한 나라로, 삼성, 현대, LG 등이 대표적인 기업들입니다. 한국은 또한 한반도 북쪽에 북한이 위치해 있어 분단된 상태이며, 남북한 간의 관계가 주요 이슈 중 하나입니다.

# %% [markdown]
# ## YAML 파일

# %%
file_path = os.path.join(base_path, "prompt02.yaml")

# %%
file_path
# Out:
# 'D:\\back_0900_mys\\python\\resource\\prompt02.yaml'

# %%
with open(file_path, "w") as f:
    f.write("""  
"_type": "prompt"
"template": "{country}에 대해서 어떻게 알고 있어요?"
"input_varoables": ["country"]
    """)

# %%
load_prompt(file_path)
# Out:
# PromptTemplate(input_variables=['country'], input_types={}, partial_variables={}, template='{country}에 대해서 어떻게 알고 있어요?')

# %%
prompt = load_prompt(file_path)

# %%
prompt.format(country="일본")
# Out:
# '일본에 대해서 어떻게 알고 있어요?'

# %%
chain = prompt | chat

# %%
result = chain.invoke({
    "country": "일본"
})

# %%
print(result.content)
# Out:
# 일본은 아시아 대륙 동쪽에 위치한 섬나라로, 동아시아에서 가장 발전된 국가 중 하나입니다. 일본은 고도의 기술력과 혁신적인 산업을 갖추고 있으며, 세계적으로 유명한 기업들이 많이 있습니다. 또한 일본은 독특한 문화와 전통을 가지고 있으며, 일본의 음식, 패션, 문화 등이 전 세계적으로 인기를 끌고 있습니다. 또한 일본은 아름다운 자연환경과 역사적인 유적지도 많이 가지고 있어서 많은 관광객들이 방문하는 인기 있는 여행지입니다.
